# %% [markdown]
# <a href="https://colab.research.google.com/github/ywei6056/Intro.-Experimental-Physics-I-NYU/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #[Introduction to Python for Science and Engineering](https://www.taylorfrancis.com/books/mono/10.1201/9780429506413/introduction-python-science-engineering-david-pine)
#
# ###The following exercises correspond to chapter [6: Plotting](https://www.taylorfrancis.com/chapters/mono/10.1201/9780429506413-6/plotting-david-pine)
#
# old manual [PyMan 0.9.31 Introduction to Python for Science](https://physics.nyu.edu/pine/pymanual/html/pymanMaster.html)
#
# in the old manual, chapter [5: Plotting](https://physics.nyu.edu/pine/pymanual/html/chap5/chap5_plot.html)

# %%
#run this block first
#this is the now standard way of interfacing with numpy and pyplot
#when you do the excercises below....
#put np. in front of any numpy commands
#e.g. np.arange instead of arange
#put plt. in front of any pyplot commands
#e.g. plt.plot
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##6.10.1
#
# Plot the function $y=3x^2$ for $-1\leq x \leq 3$ as a continuous line. Include enough points so that the curve you plot appears smooth. Label the axes $x$ and $y$. (Hint, you should first define a numpy array between -1 and 3 for x; hint hint np.linspace is your friend)

# %%
x = np.linspace(-1,3,400)
y = 3*(x**2)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ##6.10.2
#
# Plot the following function for $-15\leq x \leq 15$:
#
# $y = \frac{\cos{x}}{1+\frac{1}{5}x^2}$
#
# Include enough points so that the curve you plot appears smooth. Label the axes $x$ and $y$.

# %%
x = np.linspace(-15,15,3000)
y = (np.cos(x))/(1+(0.2*(x**2)))

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ##6.10.3
#
# Plot the functions $\sin{x}$ and $\cos{x}$ _vs_ $x$ on the same plot with $x$ going from $-\pi$ to $\pi$. Make sure the limits of the $x$-axis do not extand beyond the limits of the data. Plot $\sin{x}$ in the color orange and $\cos{x}$ in the color green and include a legend to label the two curves. Place the legend within the plot, but such that it does not cover either of the sine or cosine traces.

# %%
x = np.linspace(-1*np.pi,np.pi,624)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y1, color='orange', label='y1=sin(x)')
plt.plot(x,y2, color = 'g',label='y2=cos(x)')
plt.legend(loc = 'upper right')
plt.axhline(color="gray", y=0, linestyle = '--', zorder=-1)
plt.ylim(-1.25, 1.75)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ##6.10.5
#
# Use MatPlotLib's function `hist` along with NumPy's functions `random.rand` and `random.randn` to create the histogram graphs shown in Fig. [9.2 Histograms of random numbers.](https://physics.nyu.edu/pine/pymanual/html/chap3/chap3_arrays.html#fig-randhistos)
#
# Since the online textbook is in black and white, please refer to the linked figure from chapter 3 of the old book (in section 3.5.2)

# %%
#Add a borderline: https://www.geeksforgeeks.org/add-a-border-around-histogram-bars-in-matplotlib/
#list of colors accepted by python: https://stackoverflow.com/questions/22408237/named-colors-in-matplotlib

rand= np.random.rand(10000)
randn= np.random.randn(10000)
r = np.linspace(-5,5,100)
plt.hist([rand], bins=r, label = 'random.rand', color='slateblue', edgecolor = 'tan',  alpha = 0.75,density=True, stacked=True)
plt.hist([randn], bins=r, label='random.randn', color='forestgreen', edgecolor = 'tan', alpha = 0.75, density=True, stacked=True)
plt.xticks(np.arange(-5, 5+1, 1.0))
#print(np.arange(-5, 5+1, 1.0))
#print(type(np.arange(-5, 5+1, 1.0)))
#Help in changing tick sizes:https://stackoverflow.com/questions/12608788/changing-the-tick-frequency-on-the-x-or-y-axis

plt.ylabel('P(x)')
plt.xlabel('x')
plt.legend(loc = 'upper right')
plt.title('Frequency Distribution of 10,000 Numbers Using Python Commands')
plt.show()

# %% [markdown]
# 5.5.6 (from old book)
#
# Plot force _vs_ distance with error bars using the following data:
#
#
# ```
# d=np.array([0.38, 0.64, 0.91, 1.26, 1.41, 1.66, 1.90, 2.18]) #distance
# f=np.array([1.4, 1.65, 3.0, 3.95, 4.3, 5.20, 6.85, 7.4]) #force
# df=np.array([ 0.4, 0.5, 0.4, 0.5, 0.6, 0.5, 0.5, 0.4]) #error in force
# ```
# Your plot should also include a visual straight "best fit" to the data as well as visual "fits" that give the smallest and largest slopes consistent with the data. Note, you only need two points to define a straight line so the straight lines you draw on the plot should be arrays of length 2 and no longer. All of your fitted lines should lie _behind_ the data. Try to make your plot look like the one below.
# "Visual fit" means adjust the slope and intercept until it looks good to you by eye. Once you learn how to do a real fit, you should never do this again.
#
# ![image.png](data:image/png;base64,...)
#
# The web page [http://matplotlib.org/api/pyplot_summary.html](http://matplotlib.org/api/pyplot_summary.html) gives a summary of the main plotting commands available in MatPlotLib. The two important ones here are `plot` and `errorbar`, which make regular plots and plots with error bars, respectively. You will find the following keyword arguments useful: `yerr`, `ls`, `marker`, `mfc`, `mec`, `ms`, and `ecolor`, which you can find described by clicking on the `errorbar` function link on the web page cited above.

# %%
d=np.array([0.38, 0.64, 0.91, 1.26, 1.41, 1.66, 1.90, 2.18]) #distance
f=np.array([1.4, 1.65, 3.0, 3.95, 4.3, 5.20, 6.85, 7.4]) #force
df=np.array([ 0.4, 0.5, 0.4, 0.5, 0.6, 0.5, 0.5, 0.4]) #error in force

y1 = (7.32/2.18)*x
y2 = (7.8/2.18)*x -(.3)
y3 = (6.9/2.18)*x + (.2)

plt.errorbar(d, f, xerr=None, yerr=df, ecolor='g', fmt='ro')
plt.plot(x,y1, color='k')
plt.plot(x,y2,color='k', alpha=0.50,linestyle='--')
plt.plot(x,y3,color='k', alpha=0.50,linestyle='--')
plt.ylim(0,9)
plt.xlim(0,2.5)


plt.ylabel('force(N)')
plt.xlabel('distance(cm)')
#WHAT

plt.show()
