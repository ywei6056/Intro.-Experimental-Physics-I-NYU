# %% [markdown]
# <a href="https://colab.research.google.com/github/ywei6056/Intro.-Experimental-Physics-I-NYU/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #[Python for science and engineering](https://www.taylorfrancis.com/books/mono/10.1201/9780429506413/introduction-python-science-engineering-david-pine)
#
# ###The following exercises correspond to chapters [5: Conditionals and Loops](https://www.taylorfrancis.com/chapters/mono/10.1201/9780429506413-5/conditionals-loops-david-pine) and [7: Functions](https://www.taylorfrancis.com/chapters/mono/10.1201/9780429506413-7/functions-david-pine)
#
#
# previous manual [PyMan 0.9.31 Introduction to Python for Science](https://physics.nyu.edu/pine/pymanual/html/pymanMaster.html) chapters 6 and 7

# %% [markdown]
# ##5.4.1
#
# Write two functions to calculate the factorial of a positive integer input by the user. Recall that the factorial function is given by $x! = x (x-1) (x-2) ... (2) (1)$ so that $1!=1$, $2!=2$, $3!=6$, $4!=24$, $...$
#
# 1. Write a factorial function "FactorialW" that uses a Python `while` loop.
# 1. Write a factorial function "FactorialF" that Python `for` loop.
#
# Both functions should take a single integer argument and return the factorial of that number.
#
# Make sure your functions gracefully handle negative input.
#
# Write a for loop that prints x! for x = 1..10. Each line should output something like
#
#
# ```
# FactorialW(1) = 1 ; FactorialF(1) = 1
# ...
# FactorialW(10) = 362880 ; FactorialF(10) = 362880
# ```

# %%
def FactorialW(x):
  y = 1
  if x >=0:
    while x >0:
      y=y*x
      x=x-1
    return(y)
  else:
    print("Please give me a positive integer input")

print(FactorialW(10))
print(FactorialW(0))
print(FactorialW(-3))


def FactorialF(x):
  y = 1
  if x >=0:
    for i in range(1, x+1):
      y = y*i
    return(y)
  else:
    print("Please give me a positive integer input")

print(FactorialF(6))
print(FactorialF(0))
print(FactorialF(-3))


for i in range(1,11):
  print('FactorialW({})={}, FactorialF({})={}'.format(i, FactorialW(i), i, FactorialF(i)))
# Out:
# 3628800
# 1
# Please give me a positive integer input
# None
# 720
# 1
# Please give me a positive integer input
# None
# FactorialW(1)=1, FactorialF(1)=1
# FactorialW(2)=2, FactorialF(2)=2
# FactorialW(3)=6, FactorialF(3)=6
# FactorialW(4)=24, FactorialF(4)=24
# FactorialW(5)=120, FactorialF(5)=120
# FactorialW(6)=720, FactorialF(6)=720
# FactorialW(7)=5040, FactorialF(7)=5040
# FactorialW(8)=40320, FactorialF(8)=40320
# FactorialW(9)=362880, FactorialF(9)=362880
# FactorialW(10)=3628800, FactorialF(10)=3628800

# %% [markdown]
# ##5.4.2
#
# The following Python program finds the smallest non-trivial (not 1) prime factor of a positive integer.
#
# ```
# n = int(raw_input("Input an integer > 1: "))
# i = 2
#
# while (n % i) != 0:
#     i += 1
#
# print("The smallest factor of n is:", i )
# ```
#
# 1. Type this program into your computer and verify that it works as advertised. Then briefly explain how it works and why the while loop always terminates.
# 1. Modify the program so that it tells you if the integer input is a prime number or not. If it is not a prime number, write your program so that it prints out the smallest prime factor. Using your program verify that the following integers are prime numbers: 101, 8191, 947431.

# %%
# % means modulus. ie (3 % 7) = 3, (7 % 3) = 1

#1
n = int(input("Input an integer > 1: "))
i = 2
while (n % i) != 0:
    i += 1

print("The smallest factor of n is:", i )
print("Yes, works as advertised.")

print("ANSWER: The function works by checking the remainder between the integer n supplied by the user and, firstly, the integer 2. If this remainder is zero, it means that 2 divides n. Thus, the function would return 2 as the smallest nontrivial prime factor of n.")
print("However, if 2 does not divide n, the while loop (!= means not equal to) adds 1 to the divisor -- Now, in the next loop, the function checks to see if n is divisible by 3. If it is, the function returns 3 as the s.nt. prime factor. If it isn't, the while loop checks the next-smallest interger, 4, to see if it divides n.")
print("The function always terminates because there would eventually be an integer i, i = n, which divides n. In this case, n would be a prime number itself. And this function always neatly returns the smallest nontrivial prime factor of n because it checks for divisors of n from smallest-to-largest of all integers, ")
print("and if n has factors which are composite numbers, the smallest nontrivial prime factor if those composite numbers, being SMALLER than the composite factor itself, would have been found FIRST by the function and the while look would terminate at that point, when the smallest nontrivial prime factor is found.")
# Out:
# Input an integer > 1: 101
# The smallest factor of n is: 101
# Yes, works as advertised.
# ANSWER: The function works by checking the remainder between the integer n supplied by the user and, firstly, the integer 2. If this remainder is zero, it means that 2 divides n. Thus, the function would return 2 as the smallest nontrivial prime factor of n.
# However, if 2 does not divide n, the while loop (!= means not equal to) adds 1 to the divisor -- Now, in the next loop, the function checks to see if n is divisible by 3. If it is, the function returns 3 as the s.nt. prime factor. If it isn't, the while loop checks the next-smallest interger, 4, to see if it divides n.
# The function always terminates because there would eventually be an integer i, i = n, which divides n. In this case, n would be a prime number itself. And this function always neatly returns the smallest nontrivial prime factor of n because it checks for divisors of n from smallest-to-largest of all integers,
# and if n has factors which are composite numbers, the smallest nontrivial prime factor if those composite numbers, being SMALLER than the composite factor itself, would have been found FIRST by the function and the while look would terminate at that point, when the smallest nontrivial prime factor is found.

# %%
#2
n = int(input("Input an integer > 1: "))
i = 2
while (n % i) != 0:
    i += 1
if i == n:
  print("This number is a prime number")
else:
  print("The smallest non-trivial prime factor of {} is {}".format(n, i))


print("Yes, 101, 8191, 947431 are all prime numbers.")
# Out:
# Input an integer > 1: 8191
# This number is a prime number
# Yes, 101, 8191, 947431 are all prime numbers.

# %% [markdown]
# ##5.4.3
#
# Consider the matrix list `x = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]`. Write a list comprehension to extract the last column of the matrix `[3, 6, 9]`. Write another list comprehension to create a vector of twice the square of the middle column `[8, 50, 128]`.

# %%
x = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]


print([x[i][2] for i in range(3)])

v = [2*(x[i][1])**2 for i in range(3)]
print(v)
# Out:
# [3, 6, 9]
# [8, 50, 128]

# %% [markdown]
# ##7.6.1
#
# Write a function that can return each of the first three spherical Bessel functions $j_n(x)$:
# >$j_0(x) = \frac{\sin{x}}{x}$
#
# >$j_1(x) = \frac{\sin{x}}{x^2} - \frac{\cos{x}}{x}$
#
# >$j_2(x) = \left(\frac{3}{x^2}-1\right)\frac{\sin{x}}{x}-\frac{3\cos{x}}{x^2}$
#
# Your function should take as arguments a NumPy array $x$ and the order $n$, and should return an array of the designated order $n$ spherical Bessel function. Take care to make sure that your functions behave properly at $x=0$.
#
# Demonstrate the use of your function by writing a Python routine that plots the three Bessel functions for $0 \le x \le 20$. Your plot should look like the one below.
#
# ![image.png](data:image/png;base64,...)

# %%
def Besself(x, n):
  if n== 0:
    y0 = np.sin(x)/(x)
    for i in range(len(x)):
      if x[i]==0.0:
         y0[i]=1.0
    return(y0)    
  elif n == 1:
    y1 = np.sin(x)/x**2 - np.cos(x)/x
    for i in range(len(x)):
      if x[i]==0.0:
         y1[i]=0.0
    return(y1)
  elif n==2:
    y2 = 3*np.sin(x)/x**3 - 3*np.cos(x)/x**2 - np.sin(x)/x
    for i in range(len(x)):
      if x[i]==0.0:
        y2[i]=0.0
    return(y2)
  else:
    print("Please Input a bessel order n value between 0 and 2, inclusive")


def plotBessel(domain = np.linspace(0,20,500), n0 = False, n1=False, n2=False):
  if n0 == True:
    plt.plot(domain, Besself(domain, 0), color='blue', label='J0(x)')
  if n1 == True: 
    plt.plot(domain, Besself(domain, 1), color='green', label='J1(x)')
  if n2 == True:
    plt.plot(domain, Besself(domain, 2), color='red', label='J2(x)')
  plt.plot(domain, [0.0 for i in range(len(domain))], color='black', alpha=1, linewidth=.4)
  plt.legend(loc = 'upper right')
  plt.show()

plotBessel(n0=True)

plotBessel(n1=True)

plotBessel(n2=True)
# Out:
# <ipython-input-21-9aef387fec87>:3: RuntimeWarning: invalid value encountered in true_divide
#   y0 = np.sin(x)/(x)
# <ipython-input-21-9aef387fec87>:9: RuntimeWarning: invalid value encountered in true_divide
#   y1 = np.sin(x)/x**2 - np.cos(x)/x
# <ipython-input-21-9aef387fec87>:9: RuntimeWarning: divide by zero encountered in true_divide
#   y1 = np.sin(x)/x**2 - np.cos(x)/x
# <ipython-input-21-9aef387fec87>:15: RuntimeWarning: invalid value encountered in true_divide
#   y2 = 3*np.sin(x)/x**3 - 3*np.cos(x)/x**2 - np.sin(x)/x
# <ipython-input-21-9aef387fec87>:15: RuntimeWarning: divide by zero encountered in true_divide
#   y2 = 3*np.sin(x)/x**3 - 3*np.cos(x)/x**2 - np.sin(x)/x

# %% [markdown]
# ##7.6.2
#
# 1. Write a function that simulates the rolling of $n$ dice. Use the NumPy function `random.random_integers(6)`, which generates a random integer between 1 and 6 with equal probability (like rolling fair dice). The input of your function should be the number of dice thrown each roll and the output should be the sum of the $n$ dice.
# 1. “Roll” 2 dice 10,000 times keeping track of all the sums of each set of rolls in a list. Then use your program to generate a histogram summarizing the rolls of two dice 10,000 times. The result should look like the histogram plotted below. Use the MatPlotLib function `hist` (see http://matplotlib.org/api/pyplot_summary.html) and set the number of bins in the histogram equal to the number of different possible outcomes of a roll of your dice. For example, the sum of two dice can be anything between 2 and 12, which corresponds to 11 possible outcomes. You should get a histogram that looks like the one below.
# 1. Repeat part (b) using 3 dice and plot the resulting histogram.
#
# ![image.png](data:image/png;base64,...)

# %%
#1
def dicesum(n):
  sum= np.sum(np.random.randint(low=1, high=7, size=n))
  #https://sparkbyexamples.com/numpy/numpy-random-integer/ low:inclusive, high:exclusive, size:will give 3D arrays such as (2,4,8) 2 by 4 by 8
  return(sum)
#try:
#print(dicesum(10))

#2
result = [dicesum(2) for i in range(10000)]
#print(result[2:6])
#print(result[2])

r = np.linspace(2, 13, 12)
#note to self: linspace goes from low to high, BOTH inclusive, and cuts those into #size nmber of even pieces

plt.hist(result, bins=r)
plt.xlabel('Sum of 2 Dice')
plt.ylabel('Number of Times Occured')
plt.title('Occurance Distribution of the Sum of 2 Simultaneously-Rolled Dice, 10,000 Times')
plt.show()


#3
z = np.linspace(3, 19, 17)
result3 = [dicesum(3) for i in range(10000)]
plt.hist(result3, bins=z)
plt.xlabel('Sum of 3 Dice')
plt.ylabel('Number of Times Occured')
plt.title('Occurance Distribution of the Sum of 3 Simultaneously-Rolled Dice, 10,000 Times')
plt.show()

#note to self: if you put 12 as the higher-bond of the histogram, it won't plot the values that are actually 12. So the 'bins' argument excludes the upper bound.
# Out:
# [5 4 1 5 2 1 6 6 6 5 4 2 1 5 5 4 2 4 3 3]
